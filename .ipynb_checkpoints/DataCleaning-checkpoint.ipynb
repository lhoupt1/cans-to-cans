# %% [markdown]
# # Import Statements

# %% [markdown]
# ### I linked the google sheet to this notebook using this source: https://towardsdatascience.com/from-google-sheet-to-your-jupyter-notebook-ccdbf28fbf1b. Any updates to the google sheet will be reflected automatically in this notebook

# %%
import matplotlib.pyplot as plt 
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.graph_objects as go
import datetime

# %%
#Importing the module
import gspread
from df2gspread import df2gspread as d2g
from oauth2client.service_account import ServiceAccountCredentials

# %% [markdown]
# # Link to Google Sheets

# %% [markdown]
# Connect the Google Sheets API

# %%
#The scope is always look like this so we did not need to change anything
scope = [
   'https://spreadsheets.google.com/feeds',
         'https://www.googleapis.com/auth/drive']

#Name of our Service Account Key
google_key_file = 'jupyter-spring2020ctc-connect-3bde2ba97cd1.json'

credentials = ServiceAccountCredentials.from_json_keyfile_name(google_key_file, scope)
gc = gspread.authorize(credentials)

# %% [markdown]
# # Spring 2020 Data Cleaning

# %% [markdown]
# Open and save the "Spring 2020 CTC Recording" Google Sheets document, specifically the "Data-Analysis" sheet

# %%
#Opening the worksheet by using Worksheet ID
spring20_spreadsheet_key = '1OiGBYsa9eK26lAaznmiiczgSX17GHlOWoS0crNza-vo'
spring20_workbook = gc.open_by_key(spring20_spreadsheet_key)

#Selecting which sheet to pulling the data
spring20_sheet = spring20_workbook.worksheet('Data-Analysis')

#Pulling the data and transform it to the data frame
spring20_values = spring20_sheet.get_all_values()
spring20 = pd.DataFrame(spring20_values[1:], columns = spring20_values[0])

# %% [markdown]
# Open the dataframe

# %%
spring20.head()
# Out:
#   CURRENT STANDINGS BELOW            360            68             80  \
# 0              Fraternity  Current Total  Week 1 (2/3)  Week 2 (2/10)
# 1                 Chi Phi              0
# 2                Sigma Pi              0
# 3                     SAE              4
# 4                    Elmo              0
#
#               89           58.5          64.5                0  \
# 0  Week 3 (2/17)  Week 4 (2/14)  Week 5 (3/2)  SPR. BREAK(3/9)
# 1
# 2
# 3                                           4
# 4
#
#                    0              0              0             0  \
# 0  SPR. BREAK (3/16)  Week 6 (3/23)  Week 7 (3/30)  Week 8 (4/6)
# 1
# 2
# 3
# 4
#
#                0               0
# 0  Week 9 (4/13)  Week 10 (4/20)
# 1
# 2
# 3
# 4

# %% [markdown]
# Fill blank cells with NA's

# %%
spring20.replace(r'', np.NaN, inplace=True)
spring20.head()
# Out:
#   CURRENT STANDINGS BELOW            360            68             80  \
# 0              Fraternity  Current Total  Week 1 (2/3)  Week 2 (2/10)
# 1                 Chi Phi              0           NaN            NaN
# 2                Sigma Pi              0           NaN            NaN
# 3                     SAE              4           NaN            NaN
# 4                    Elmo              0           NaN            NaN
#
#               89           58.5          64.5                0  \
# 0  Week 3 (2/17)  Week 4 (2/14)  Week 5 (3/2)  SPR. BREAK(3/9)
# 1            NaN            NaN           NaN              NaN
# 2            NaN            NaN           NaN              NaN
# 3            NaN            NaN             4              NaN
# 4            NaN            NaN           NaN              NaN
#
#                    0              0              0             0  \
# 0  SPR. BREAK (3/16)  Week 6 (3/23)  Week 7 (3/30)  Week 8 (4/6)
# 1                NaN            NaN            NaN           NaN
# 2                NaN            NaN            NaN           NaN
# 3                NaN            NaN            NaN           NaN
# 4                NaN            NaN            NaN           NaN
#
#                0               0
# 0  Week 9 (4/13)  Week 10 (4/20)
# 1            NaN             NaN
# 2            NaN             NaN
# 3            NaN             NaN
# 4            NaN             NaN

# %% [markdown]
# Replace the header with the second row of the dataframe

# %%
new_header = spring20.iloc[0] # grab the first row for the header
spring20 = spring20[1:] # take the data less the header row
spring20.columns = new_header # set the header row as the spring20 header
spring20.head()
# Out:
# 0 Fraternity Current Total Week 1 (2/3) Week 2 (2/10) Week 3 (2/17)  \
# 1    Chi Phi             0          NaN           NaN           NaN
# 2   Sigma Pi             0          NaN           NaN           NaN
# 3        SAE             4          NaN           NaN           NaN
# 4       Elmo             0          NaN           NaN           NaN
# 5        NaN            22          NaN             3             2
#
# 0 Week 4 (2/14) Week 5 (3/2) SPR. BREAK(3/9) SPR. BREAK (3/16) Week 6 (3/23)  \
# 1           NaN          NaN             NaN               NaN           NaN
# 2           NaN          NaN             NaN               NaN           NaN
# 3           NaN            4             NaN               NaN           NaN
# 4           NaN          NaN             NaN               NaN           NaN
# 5           3.5         13.5             NaN               NaN           NaN
#
# 0 Week 7 (3/30) Week 8 (4/6) Week 9 (4/13) Week 10 (4/20)
# 1           NaN          NaN           NaN            NaN
# 2           NaN          NaN           NaN            NaN
# 3           NaN          NaN           NaN            NaN
# 4           NaN          NaN           NaN            NaN
# 5           NaN          NaN           NaN            NaN

# %% [markdown]
# Drop "Current Total" column- we will not be needing this

# %%
spring20.columns
spring20.drop(columns=['Current Total'], inplace=True) # drop irrelevant column
spring20.head()
# Out:
# 0 Fraternity Week 1 (2/3) Week 2 (2/10) Week 3 (2/17) Week 4 (2/14)  \
# 1    Chi Phi          NaN           NaN           NaN           NaN
# 2   Sigma Pi          NaN           NaN           NaN           NaN
# 3        SAE          NaN           NaN           NaN           NaN
# 4       Elmo          NaN           NaN           NaN           NaN
# 5        NaN          NaN             3             2           3.5
#
# 0 Week 5 (3/2) SPR. BREAK(3/9) SPR. BREAK (3/16) Week 6 (3/23) Week 7 (3/30)  \
# 1          NaN             NaN               NaN           NaN           NaN
# 2          NaN             NaN               NaN           NaN           NaN
# 3            4             NaN               NaN           NaN           NaN
# 4          NaN             NaN               NaN           NaN           NaN
# 5         13.5             NaN               NaN           NaN           NaN
#
# 0 Week 8 (4/6) Week 9 (4/13) Week 10 (4/20)
# 1          NaN           NaN            NaN
# 2          NaN           NaN            NaN
# 3          NaN           NaN            NaN
# 4          NaN           NaN            NaN
# 5          NaN           NaN            NaN

# %% [markdown]
# Delete scrap notes at the bottom of the sheet

# %%
spring20 = spring20.iloc[0:44,] # keep only relevant rows

# %% [markdown]
# Fill NA's in "Fraternity" column using the forward fill method as appropriate

# %%
spring20['Fraternity'].fillna(method='ffill', inplace=True) # forward fill NA values for Fraternity name 
spring20.head()
# Out:
# 0 Fraternity Week 1 (2/3) Week 2 (2/10) Week 3 (2/17) Week 4 (2/14)  \
# 1    Chi Phi          NaN           NaN           NaN           NaN
# 2   Sigma Pi          NaN           NaN           NaN           NaN
# 3        SAE          NaN           NaN           NaN           NaN
# 4       Elmo          NaN           NaN           NaN           NaN
# 5       Elmo          NaN             3             2           3.5
#
# 0 Week 5 (3/2) SPR. BREAK(3/9) SPR. BREAK (3/16) Week 6 (3/23) Week 7 (3/30)  \
# 1          NaN             NaN               NaN           NaN           NaN
# 2          NaN             NaN               NaN           NaN           NaN
# 3            4             NaN               NaN           NaN           NaN
# 4          NaN             NaN               NaN           NaN           NaN
# 5         13.5             NaN               NaN           NaN           NaN
#
# 0 Week 8 (4/6) Week 9 (4/13) Week 10 (4/20)
# 1          NaN           NaN            NaN
# 2          NaN           NaN            NaN
# 3          NaN           NaN            NaN
# 4          NaN           NaN            NaN
# 5          NaN           NaN            NaN

# %% [markdown]
# Delete rows with empty weekly bags data (duplicate rows of each house caused by formats of the google sheet)

# %%
spring20 = spring20[~spring20['Fraternity'].duplicated(keep=False) |
                    spring20[spring20.columns[1:]].notnull().any(axis=1)]
spring20.head()
# Out:
# 0 Fraternity Week 1 (2/3) Week 2 (2/10) Week 3 (2/17) Week 4 (2/14)  \
# 1    Chi Phi          NaN           NaN           NaN           NaN
# 2   Sigma Pi          NaN           NaN           NaN           NaN
# 3        SAE          NaN           NaN           NaN           NaN
# 5       Elmo          NaN             3             2           3.5
# 7  Delta Sig          NaN           NaN           3.5             7
#
# 0 Week 5 (3/2) SPR. BREAK(3/9) SPR. BREAK (3/16) Week 6 (3/23) Week 7 (3/30)  \
# 1          NaN             NaN               NaN           NaN           NaN
# 2          NaN             NaN               NaN           NaN           NaN
# 3            4             NaN               NaN           NaN           NaN
# 5         13.5             NaN               NaN           NaN           NaN
# 7          NaN             NaN               NaN           NaN           NaN
#
# 0 Week 8 (4/6) Week 9 (4/13) Week 10 (4/20)
# 1          NaN           NaN            NaN
# 2          NaN           NaN            NaN
# 3          NaN           NaN            NaN
# 5          NaN           NaN            NaN
# 7          NaN           NaN            NaN

# %% [markdown]
# Tidy the dataframe by melting the week columns into a better format

# %%
spring20 = pd.melt(spring20, id_vars=['Fraternity'], value_vars=spring20.columns[1:])
spring20.columns=['Fraternity', 'Week', 'Bags']
spring20.head()
# Out:
#   Fraternity          Week Bags
# 0    Chi Phi  Week 1 (2/3)  NaN
# 1   Sigma Pi  Week 1 (2/3)  NaN
# 2        SAE  Week 1 (2/3)  NaN
# 3       Elmo  Week 1 (2/3)  NaN
# 4  Delta Sig  Week 1 (2/3)  NaN

# %% [markdown]
# Convert "Week" column into standard date-time string, and convert to date-time type

# %%
spring20['Week'] = spring20['Week'].apply(lambda x: x[x.find('(')+1:-1] + '/20')
spring20['Week']= pd.to_datetime(spring20['Week'].astype(str), format='%m/%d/%y')
spring20.head()
# Out:
#   Fraternity       Week Bags
# 0    Chi Phi 2020-02-03  NaN
# 1   Sigma Pi 2020-02-03  NaN
# 2        SAE 2020-02-03  NaN
# 3       Elmo 2020-02-03  NaN
# 4  Delta Sig 2020-02-03  NaN

# %% [markdown]
# Fill NaN with 0's and convert "Bags" column to float type.

# %%
spring20.fillna(0, inplace=True)
spring20['Bags'] = pd.to_numeric(spring20['Bags'])
spring20.head()
# Out:
#   Fraternity       Week  Bags
# 0    Chi Phi 2020-02-03   0.0
# 1   Sigma Pi 2020-02-03   0.0
# 2        SAE 2020-02-03   0.0
# 3       Elmo 2020-02-03   0.0
# 4  Delta Sig 2020-02-03   0.0

# %% [markdown]
# Add "Spring 2020" label. Enjoy clean and tidy data!

# %%
spring20['Semester'] = 'Spring 2020'
spring20.head()
# Out:
#   Fraternity       Week  Bags     Semester
# 0    Chi Phi 2020-02-03   0.0  Spring 2020
# 1   Sigma Pi 2020-02-03   0.0  Spring 2020
# 2        SAE 2020-02-03   0.0  Spring 2020
# 3       Elmo 2020-02-03   0.0  Spring 2020
# 4  Delta Sig 2020-02-03   0.0  Spring 2020

# %% [markdown]
# # Fall 2019 Data Cleaning

# %% [markdown]
# Open and save the "Fall 2019 CTC Recording" Google Sheets document, specifically the "Data-Analysis" sheet

# %%
#Opening the worksheet by using Worksheet ID
fall19_spreadsheet_key = '14BYq15BfBUclNLbO8IRSAQeG98qCGDG3n59Hkfh3huU'
fall19_workbook = gc.open_by_key(fall19_spreadsheet_key)

#Selecting which sheet to pulling the data
fall19_sheet = fall19_workbook.worksheet('Data-Analysis')

#Pulling the data and transform it to the data frame
fall19_values = fall19_sheet.get_all_values()
fall19 = pd.DataFrame(fall19_values[1:], columns = fall19_values[0])

# %% [markdown]
# Open the dataframe

# %%
fall19.head()
# Out:
#   CURRENT STANDINGS BELOW          550.5            32           47.5  \
# 0              Fraternity  Current Total  Week 1 (9/8)  Week 2 (9/15)
# 1                 Chi Phi              0
# 2                Sigma Pi              0
# 3                     SAE              9
# 4                                      0
#
#             38.5             25            56.5           107.5  \
# 0  Week 3 (9/22)  Week 4 (9/29)  Week 5 (10/13)  Week 6 (10/20)
# 1
# 2
# 3                                                             9
# 4
#
#              24.5             72              77             40.5  \
# 0  Week 7 (10/27)  Week 8 (11/3)  Week 9 (11/10)  Week 10 (11/17)
# 1
# 2
# 3
# 4
#
#               29.5
# 0  Week 11 (11/24)
# 1
# 2
# 3
# 4

# %% [markdown]
# Fill blank cells with NA's

# %%
fall19.replace(r'', np.NaN, inplace=True)
fall19.head()
# Out:
#   CURRENT STANDINGS BELOW          550.5            32           47.5  \
# 0              Fraternity  Current Total  Week 1 (9/8)  Week 2 (9/15)
# 1                 Chi Phi              0           NaN            NaN
# 2                Sigma Pi              0           NaN            NaN
# 3                     SAE              9           NaN            NaN
# 4                     NaN              0           NaN            NaN
#
#             38.5             25            56.5           107.5  \
# 0  Week 3 (9/22)  Week 4 (9/29)  Week 5 (10/13)  Week 6 (10/20)
# 1            NaN            NaN             NaN             NaN
# 2            NaN            NaN             NaN             NaN
# 3            NaN            NaN             NaN               9
# 4            NaN            NaN             NaN             NaN
#
#              24.5             72              77             40.5  \
# 0  Week 7 (10/27)  Week 8 (11/3)  Week 9 (11/10)  Week 10 (11/17)
# 1             NaN            NaN             NaN              NaN
# 2             NaN            NaN             NaN              NaN
# 3             NaN            NaN             NaN              NaN
# 4             NaN            NaN             NaN              NaN
#
#               29.5
# 0  Week 11 (11/24)
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %% [markdown]
# Replace the header with the second row of the dataframe

# %%
new_header = fall19.iloc[0] # grab the first row for the header
fall19 = fall19[1:] # take the data less the header row
fall19.columns = new_header # set the header row as the spring20 header
fall19.head()
# Out:
# 0 Fraternity Current Total Week 1 (9/8) Week 2 (9/15) Week 3 (9/22)  \
# 1    Chi Phi             0          NaN           NaN           NaN
# 2   Sigma Pi             0          NaN           NaN           NaN
# 3        SAE             9          NaN           NaN           NaN
# 4        NaN             0          NaN           NaN           NaN
# 5       Elmo             0          NaN           NaN           NaN
#
# 0 Week 4 (9/29) Week 5 (10/13) Week 6 (10/20) Week 7 (10/27) Week 8 (11/3)  \
# 1           NaN            NaN            NaN            NaN           NaN
# 2           NaN            NaN            NaN            NaN           NaN
# 3           NaN            NaN              9            NaN           NaN
# 4           NaN            NaN            NaN            NaN           NaN
# 5           NaN            NaN            NaN            NaN           NaN
#
# 0 Week 9 (11/10) Week 10 (11/17) Week 11 (11/24)
# 1            NaN             NaN             NaN
# 2            NaN             NaN             NaN
# 3            NaN             NaN             NaN
# 4            NaN             NaN             NaN
# 5            NaN             NaN             NaN

# %% [markdown]
# Drop "Current Total" column- we will not be needing this

# %%
fall19.columns
fall19.drop(columns=['Current Total'], inplace=True) # drop irrelevant column
fall19.head()
# Out:
# 0 Fraternity Week 1 (9/8) Week 2 (9/15) Week 3 (9/22) Week 4 (9/29)  \
# 1    Chi Phi          NaN           NaN           NaN           NaN
# 2   Sigma Pi          NaN           NaN           NaN           NaN
# 3        SAE          NaN           NaN           NaN           NaN
# 4        NaN          NaN           NaN           NaN           NaN
# 5       Elmo          NaN           NaN           NaN           NaN
#
# 0 Week 5 (10/13) Week 6 (10/20) Week 7 (10/27) Week 8 (11/3) Week 9 (11/10)  \
# 1            NaN            NaN            NaN           NaN            NaN
# 2            NaN            NaN            NaN           NaN            NaN
# 3            NaN              9            NaN           NaN            NaN
# 4            NaN            NaN            NaN           NaN            NaN
# 5            NaN            NaN            NaN           NaN            NaN
#
# 0 Week 10 (11/17) Week 11 (11/24)
# 1             NaN             NaN
# 2             NaN             NaN
# 3             NaN             NaN
# 4             NaN             NaN
# 5             NaN             NaN

# %% [markdown]
# Delete scrap notes at the bottom of the sheet

# %%
fall19 = fall19.iloc[0:47,] # keep only relevant rows

# %% [markdown]
# Fill NA's in "Fraternity" column using the forward fill method as appropriate

# %%
fall19['Fraternity'].fillna(method='ffill', inplace=True) # forward fill NA values for Fraternity name 
fall19.head()
# Out:
# 0 Fraternity Week 1 (9/8) Week 2 (9/15) Week 3 (9/22) Week 4 (9/29)  \
# 1    Chi Phi          NaN           NaN           NaN           NaN
# 2   Sigma Pi          NaN           NaN           NaN           NaN
# 3        SAE          NaN           NaN           NaN           NaN
# 4        SAE          NaN           NaN           NaN           NaN
# 5       Elmo          NaN           NaN           NaN           NaN
#
# 0 Week 5 (10/13) Week 6 (10/20) Week 7 (10/27) Week 8 (11/3) Week 9 (11/10)  \
# 1            NaN            NaN            NaN           NaN            NaN
# 2            NaN            NaN            NaN           NaN            NaN
# 3            NaN              9            NaN           NaN            NaN
# 4            NaN            NaN            NaN           NaN            NaN
# 5            NaN            NaN            NaN           NaN            NaN
#
# 0 Week 10 (11/17) Week 11 (11/24)
# 1             NaN             NaN
# 2             NaN             NaN
# 3             NaN             NaN
# 4             NaN             NaN
# 5             NaN             NaN

# %% [markdown]
# Delete rows with empty weekly bags data (duplicate rows of each house caused by formats of the google sheet)

# %%
fall19 = fall19[~fall19['Fraternity'].duplicated(keep=False) |
                    fall19[fall19.columns[1:]].notnull().any(axis=1)]
fall19.head()
# Out:
# 0 Fraternity Week 1 (9/8) Week 2 (9/15) Week 3 (9/22) Week 4 (9/29)  \
# 1    Chi Phi          NaN           NaN           NaN           NaN
# 2   Sigma Pi          NaN           NaN           NaN           NaN
# 3        SAE          NaN           NaN           NaN           NaN
# 7       Elmo          8.5           NaN             4           NaN
# 9  Delta Sig            2           NaN           NaN             7
#
# 0 Week 5 (10/13) Week 6 (10/20) Week 7 (10/27) Week 8 (11/3) Week 9 (11/10)  \
# 1            NaN            NaN            NaN           NaN            NaN
# 2            NaN            NaN            NaN           NaN            NaN
# 3            NaN              9            NaN           NaN            NaN
# 7              9              1            NaN            17              9
# 9            NaN            3.5            NaN            12            NaN
#
# 0 Week 10 (11/17) Week 11 (11/24)
# 1             NaN             NaN
# 2             NaN             NaN
# 3             NaN             NaN
# 7               5             NaN
# 9             1.5             NaN

# %% [markdown]
# Tidy the dataframe by melting the week columns into a better format

# %%
fall19 = pd.melt(fall19, id_vars=['Fraternity'], value_vars=fall19.columns[1:])
fall19.columns=['Fraternity', 'Week', 'Bags']
fall19.head()
# Out:
#   Fraternity          Week Bags
# 0    Chi Phi  Week 1 (9/8)  NaN
# 1   Sigma Pi  Week 1 (9/8)  NaN
# 2        SAE  Week 1 (9/8)  NaN
# 3       Elmo  Week 1 (9/8)  8.5
# 4  Delta Sig  Week 1 (9/8)    2

# %% [markdown]
# Convert "Week" column into standard date-time string, and convert to date-time type

# %%
fall19['Week'] = fall19['Week'].apply(lambda x: x[x.find('(')+1:-1] + '/19')
fall19['Week']= pd.to_datetime(fall19['Week'].astype(str), format='%m/%d/%y')
fall19.head()
# Out:
#   Fraternity       Week Bags
# 0    Chi Phi 2019-09-08  NaN
# 1   Sigma Pi 2019-09-08  NaN
# 2        SAE 2019-09-08  NaN
# 3       Elmo 2019-09-08  8.5
# 4  Delta Sig 2019-09-08    2

# %% [markdown]
# Fill NaN with 0's and convert "Bags" column to float type.

# %%
fall19.fillna(0, inplace=True)
fall19['Bags'] = pd.to_numeric(fall19['Bags'])
fall19.head()
# Out:
#   Fraternity       Week  Bags
# 0    Chi Phi 2019-09-08   0.0
# 1   Sigma Pi 2019-09-08   0.0
# 2        SAE 2019-09-08   0.0
# 3       Elmo 2019-09-08   8.5
# 4  Delta Sig 2019-09-08   2.0

# %% [markdown]
# Add "Fall 2019" label. Enjoy clean and tidy data!

# %%
fall19['Semester'] = 'Fall 2019'
fall19.head()
# Out:
#   Fraternity       Week  Bags   Semester
# 0    Chi Phi 2019-09-08   0.0  Fall 2019
# 1   Sigma Pi 2019-09-08   0.0  Fall 2019
# 2        SAE 2019-09-08   0.0  Fall 2019
# 3       Elmo 2019-09-08   8.5  Fall 2019
# 4  Delta Sig 2019-09-08   2.0  Fall 2019

# %% [markdown]
# # Spring 2019 Data Cleaning

# %% [markdown]
# Open and save the "Spring 2019 CTC Recording" Google Sheets document, specifically the "Data-Analysis" sheet

# %%
#Opening the worksheet by using Worksheet ID
spring19_spreadsheet_key = '1tEiEe2UfWBQr1W2BncKevsvF-SG6XbLl-H1uDYgWF9w'
spring19_workbook = gc.open_by_key(spring19_spreadsheet_key)

#Selecting which sheet to pulling the data
spring19_sheet = spring19_workbook.worksheet('Data-Analysis')

#Pulling the data and transform it to the data frame
spring19_values = spring19_sheet.get_all_values()
spring19 = pd.DataFrame(spring19_values[1:], columns = spring19_values[0])

# %% [markdown]
# Open the dataframe

# %%
spring19.head()
# Out:
#                            Monday Feb, 18          Monday Feb, 25  \
# 0                  Frats to pick up from:  Frats to pick up from:
# 1  Kappa Sig (2 large bags back porch - 4                ksig - 2
# 2                 ATO (8 small bags ) - 6              dke - 15.5
# 3     Alpha sig (@ house and wertland - 7              sig nu - 7
# 4                              Sig Nu - 2                serp - 5
#
#             Monday Mar, 4 Monday Mar, 11          Monday Mar, 18  \
# 0  Frats to pick up from:           N/A:  Frats to pick up from:
# 1                aepi - 4
# 2                 ka - 11
# 3              sig nu - 8
# 4              a sig - 13
#
#            Monday Mar, 25           Monday Apr, 1           Monday Apr, 8  \
# 0  Frats to pick up from:  Frats to pick up from:  Frats to pick up from:
# 1                 aepi- 5           alpha sig - 7              sig nu - 8
# 2              a sig - 10              sig nu - 6                surp - 7
# 3             phi psi - 4           kappa sig - 6                aepi - 5
# 4               hall - 15                aepi - 2          alpha sig - 17
#
#            Monday Apr, 15          Monday Apr, 22
# 0  Frats to pick up from:  Frats to pick up from:
# 1             chi phi - 5                  ka - 6
# 2                 ka - 11                aepi - 3
# 3              sig pi - 3          alpha sig - 14
# 4         alpha sig - 1.5

# %% [markdown]
# Fill blank cells with NA's

# %%
spring19.replace(r'', np.NaN, inplace=True)
spring19.head()
# Out:
#                            Monday Feb, 18          Monday Feb, 25  \
# 0                  Frats to pick up from:  Frats to pick up from:
# 1  Kappa Sig (2 large bags back porch - 4                ksig - 2
# 2                 ATO (8 small bags ) - 6              dke - 15.5
# 3     Alpha sig (@ house and wertland - 7              sig nu - 7
# 4                              Sig Nu - 2                serp - 5
#
#             Monday Mar, 4 Monday Mar, 11          Monday Mar, 18  \
# 0  Frats to pick up from:           N/A:  Frats to pick up from:
# 1                aepi - 4            NaN                     NaN
# 2                 ka - 11            NaN                     NaN
# 3              sig nu - 8            NaN                     NaN
# 4              a sig - 13            NaN                     NaN
#
#            Monday Mar, 25           Monday Apr, 1           Monday Apr, 8  \
# 0  Frats to pick up from:  Frats to pick up from:  Frats to pick up from:
# 1                 aepi- 5           alpha sig - 7              sig nu - 8
# 2              a sig - 10              sig nu - 6                surp - 7
# 3             phi psi - 4           kappa sig - 6                aepi - 5
# 4               hall - 15                aepi - 2          alpha sig - 17
#
#            Monday Apr, 15          Monday Apr, 22
# 0  Frats to pick up from:  Frats to pick up from:
# 1             chi phi - 5                  ka - 6
# 2                 ka - 11                aepi - 3
# 3              sig pi - 3          alpha sig - 14
# 4         alpha sig - 1.5                     NaN

# %% [markdown]
# Delete first row

# %%
spring19 = spring19.iloc[1:,] # keep only relevant rows
spring19.head()
# Out:
#                            Monday Feb, 18 Monday Feb, 25 Monday Mar, 4  \
# 1  Kappa Sig (2 large bags back porch - 4       ksig - 2      aepi - 4
# 2                 ATO (8 small bags ) - 6     dke - 15.5       ka - 11
# 3     Alpha sig (@ house and wertland - 7     sig nu - 7    sig nu - 8
# 4                              Sig Nu - 2       serp - 5    a sig - 13
# 5                             chi phi - 2  alpha sig - 5    k sig - 10
#
#   Monday Mar, 11 Monday Mar, 18 Monday Mar, 25  Monday Apr, 1   Monday Apr, 8  \
# 1            NaN            NaN        aepi- 5  alpha sig - 7      sig nu - 8
# 2            NaN            NaN     a sig - 10     sig nu - 6        surp - 7
# 3            NaN            NaN    phi psi - 4  kappa sig - 6        aepi - 5
# 4            NaN            NaN      hall - 15       aepi - 2  alpha sig - 17
# 5            NaN            NaN      surp - 10     figi - 2.5  kappa sig - 10
#
#     Monday Apr, 15  Monday Apr, 22
# 1      chi phi - 5          ka - 6
# 2          ka - 11        aepi - 3
# 3       sig pi - 3  alpha sig - 14
# 4  alpha sig - 1.5             NaN
# 5      fiji - 23.5             NaN

# %% [markdown]
# Transpose the dataframe (inverse rows and columns)

# %%
spring19 = spring19.transpose()
spring19.head()
# Out:
#                                                      1  \
# Monday Feb, 18  Kappa Sig (2 large bags back porch - 4
# Monday Feb, 25                                ksig - 2
# Monday Mar, 4                                 aepi - 4
# Monday Mar, 11                                     NaN
# Monday Mar, 18                                     NaN
#
#                                       2                                    3  \
# Monday Feb, 18  ATO (8 small bags ) - 6  Alpha sig (@ house and wertland - 7
# Monday Feb, 25               dke - 15.5                           sig nu - 7
# Monday Mar, 4                   ka - 11                           sig nu - 8
# Monday Mar, 11                      NaN                                  NaN
# Monday Mar, 18                      NaN                                  NaN
#
#                          4              5         6         7          8  \
# Monday Feb, 18  Sig Nu - 2    chi phi - 2       NaN       NaN        NaN
# Monday Feb, 25    serp - 5  alpha sig - 5       NaN       NaN        NaN
# Monday Mar, 4   a sig - 13     k sig - 10  elmo - 5  surp - 5  hall - 16
# Monday Mar, 11         NaN            NaN       NaN       NaN        NaN
# Monday Mar, 18         NaN            NaN       NaN       NaN        NaN
#
#                          9   10   11
# Monday Feb, 18         NaN  NaN  NaN
# Monday Feb, 25         NaN  NaN  NaN
# Monday Mar, 4   sig pi - 4  NaN  NaN
# Monday Mar, 11         NaN  NaN  NaN
# Monday Mar, 18         NaN  NaN  NaN

# %% [markdown]
# Make the index it's own column, labeled "Week"

# %%
spring19['Week'] = spring19.index
spring19.head()
# Out:
#                                                      1  \
# Monday Feb, 18  Kappa Sig (2 large bags back porch - 4
# Monday Feb, 25                                ksig - 2
# Monday Mar, 4                                 aepi - 4
# Monday Mar, 11                                     NaN
# Monday Mar, 18                                     NaN
#
#                                       2                                    3  \
# Monday Feb, 18  ATO (8 small bags ) - 6  Alpha sig (@ house and wertland - 7
# Monday Feb, 25               dke - 15.5                           sig nu - 7
# Monday Mar, 4                   ka - 11                           sig nu - 8
# Monday Mar, 11                      NaN                                  NaN
# Monday Mar, 18                      NaN                                  NaN
#
#                          4              5         6         7          8  \
# Monday Feb, 18  Sig Nu - 2    chi phi - 2       NaN       NaN        NaN
# Monday Feb, 25    serp - 5  alpha sig - 5       NaN       NaN        NaN
# Monday Mar, 4   a sig - 13     k sig - 10  elmo - 5  surp - 5  hall - 16
# Monday Mar, 11         NaN            NaN       NaN       NaN        NaN
# Monday Mar, 18         NaN            NaN       NaN       NaN        NaN
#
#                          9   10   11            Week
# Monday Feb, 18         NaN  NaN  NaN  Monday Feb, 18
# Monday Feb, 25         NaN  NaN  NaN  Monday Feb, 25
# Monday Mar, 4   sig pi - 4  NaN  NaN   Monday Mar, 4
# Monday Mar, 11         NaN  NaN  NaN  Monday Mar, 11
# Monday Mar, 18         NaN  NaN  NaN  Monday Mar, 18

# %% [markdown]
# Tidy the dataframe by melting the columns into a better format

# %%
spring19 = pd.melt(spring19, id_vars=['Week'], value_vars=spring19.columns[:-1])
spring19.drop(columns=['variable'], inplace=True) # drop irrelevant column
spring19.columns=['Week', 'Fraternity']
spring19.head()
# Out:
#              Week                              Fraternity
# 0  Monday Feb, 18  Kappa Sig (2 large bags back porch - 4
# 1  Monday Feb, 25                                ksig - 2
# 2   Monday Mar, 4                                aepi - 4
# 3  Monday Mar, 11                                     NaN
# 4  Monday Mar, 18                                     NaN

# %% [markdown]
# Extract number of bags and fraternity label into own columns, convert bags to numeric type

# %%
spring19['Bags'] = spring19['Fraternity'].str.split('- ', expand=True)[1]
spring19['Fraternity'] = spring19['Fraternity'].str.split('- ', expand=True)[0]
spring19.head()
# Out:
#              Week                           Fraternity Bags
# 0  Monday Feb, 18  Kappa Sig (2 large bags back porch     4
# 1  Monday Feb, 25                                ksig     2
# 2   Monday Mar, 4                                aepi     4
# 3  Monday Mar, 11                                  NaN  NaN
# 4  Monday Mar, 18                                  NaN  NaN

# %% [markdown]
# Fill NAN in "Bags" column with 0's and convert column to float type

# %%
spring19['Bags'].fillna(0, inplace=True)
spring19['Bags'] = pd.to_numeric(spring19['Bags'])
spring19.head()
# Out:
#              Week                           Fraternity  Bags
# 0  Monday Feb, 18  Kappa Sig (2 large bags back porch    4.0
# 1  Monday Feb, 25                                ksig    2.0
# 2   Monday Mar, 4                                aepi    4.0
# 3  Monday Mar, 11                                  NaN   0.0
# 4  Monday Mar, 18                                  NaN   0.0

# %% [markdown]
# Replace inconsistent fraternity labels with standard label

# %%
spring19['Fraternity'].replace(['Kappa Sig (2 large bags back porch ', 'k sig ', 'ksig ', 'kappa sig '], 'Kappa Sig', inplace=True)
spring19['Fraternity'].replace(['aepi ', 'aepi'], 'AEPi', inplace=True)
spring19['Fraternity'].replace(['alpha sig ', 'a sig ', 'Alpha sig (@ house and wertland '], 'Alpha Sig', inplace=True)
spring19['Fraternity'].replace(['sig nu ', 'Sig Nu '], 'Sigma Nu', inplace=True)
spring19['Fraternity'].replace('chi phi ', 'Chi Phi', inplace=True)
spring19['Fraternity'].replace(['ka ', 'ka  '], 'KA', inplace=True)
spring19['Fraternity'].replace(['ATO (8 small bags ) ', 'ato '], 'ATO', inplace=True)
spring19['Fraternity'].replace('dke ', 'DKE', inplace=True)
spring19['Fraternity'].replace(['surp ', 'serp '], 'SERP', inplace=True)
spring19['Fraternity'].replace(['phi psi '], 'Phi Psi', inplace=True)
spring19['Fraternity'].replace('sig pi ', 'Sigma Pi', inplace=True)
spring19['Fraternity'].replace('hall ', 'The Hall', inplace=True)
spring19['Fraternity'].replace(['figi ', 'fiji ',], 'Fiji', inplace=True)
spring19['Fraternity'].replace('elmo ', 'Elmo', inplace=True)
spring19.head()
# Out:
#              Week Fraternity  Bags
# 0  Monday Feb, 18  Kappa Sig   4.0
# 1  Monday Feb, 25  Kappa Sig   2.0
# 2   Monday Mar, 4       AEPi   4.0
# 3  Monday Mar, 11        NaN   0.0
# 4  Monday Mar, 18        NaN   0.0

# %% [markdown]
# Remove rows with NAN values in the "Fraternity" column

# %%
spring19 = spring19[spring19['Fraternity'].notnull()]
spring19.head()
# Out:
#              Week Fraternity  Bags
# 0  Monday Feb, 18  Kappa Sig   4.0
# 1  Monday Feb, 25  Kappa Sig   2.0
# 2   Monday Mar, 4       AEPi   4.0
# 5  Monday Mar, 25       AEPi   5.0
# 6   Monday Apr, 1  Alpha Sig   7.0

# %% [markdown]
# Convert "Week" column into standard date-time string, and convert to date-time type

# %%
spring19['Week'] = spring19['Week'].str.split(" ", 1, expand=True)[1] + ', 19'
# spring19['Week']= pd.to_datetime(spring19['Week'].astype(str), format='%b, %d, %y')
spring19.head()
# Out:
#           Week Fraternity  Bags
# 0  Feb, 18, 19  Kappa Sig   4.0
# 1  Feb, 25, 19  Kappa Sig   2.0
# 2   Mar, 4, 19       AEPi   4.0
# 5  Mar, 25, 19       AEPi   5.0
# 6   Apr, 1, 19  Alpha Sig   7.0

# %% [markdown]
# Add "Spring 2019" label. Enjoy clean and tidy data!

# %%
spring19['Semester'] = 'Spring 2019'
spring19.head()
# Out:
#           Week Fraternity  Bags     Semester
# 0  Feb, 18, 19  Kappa Sig   4.0  Spring 2019
# 1  Feb, 25, 19  Kappa Sig   2.0  Spring 2019
# 2   Mar, 4, 19       AEPi   4.0  Spring 2019
# 5  Mar, 25, 19       AEPi   5.0  Spring 2019
# 6   Apr, 1, 19  Alpha Sig   7.0  Spring 2019

# %% [markdown]
# # Fall 2018 Data Cleaning

# %% [markdown]
# Open and save the "Fall 2018 Reconstructed" Google Sheets document, specifically the "Data-Analysis" sheet

# %%
#Opening the worksheet by using Worksheet ID
fall18_spreadsheet_key = '1LBadgog3gZmLVSYnshCMkoGDUHE0r6Gya_WOjt5sNHM'
fall18_workbook = gc.open_by_key(fall18_spreadsheet_key)

#Selecting which sheet to pulling the data
fall18_sheet = fall18_workbook.worksheet('Data-Analysis')

#Pulling the data and transform it to the data frame
fall18_values = fall18_sheet.get_all_values()
fall18 = pd.DataFrame(fall18_values[1:], columns = fall18_values[0])

# %% [markdown]
# Open the dataframe

# %%
fall18.head()
# Out:
#   Fraternity Number of Bags Fall 2018 Semester Dec 9 Dec 2 Nov 30 Oct 18  \
# 0    Chi Phi                                57    20     4     21     12
# 1   Sigma Pi                                32           5     16     11
# 2        SAE                                 6                         6
# 3       Elmo
# 4  Delta Sig                               2.5                2.5
#
#   Bonus      Dec 2 total     Nov 30 total       Oct 18 total
# 0    20    1) Chi Phi 37    1. Chi Phi 33      1. Chi Phi 12
# 1     1  2) Kappa Sig 34  2. Kappa Sig 32    2. Kappa Sig 12
# 2         3) Sigma Pi 32   3. Sigma Pi 27  3. Alpha Sig 11.5
# 3        4) Alpha Sig 24  4. Alpha Sig 24     4. Sigma Pi 11
# 4                                                   5. SAE 6

# %% [markdown]
# Drop irrelevant data (columns 7+)

# %%
fall18.drop(fall18.columns[6:], axis=1, inplace=True) # drop irrelevant column
fall18.drop(columns=['Number of Bags Fall 2018 Semester'], inplace=True) # drop irrelevant column
fall18.head()
# Out:
#   Fraternity Dec 9 Dec 2 Nov 30 Oct 18
# 0    Chi Phi    20     4     21     12
# 1   Sigma Pi           5     16     11
# 2        SAE                         6
# 3       Elmo
# 4  Delta Sig                2.5

# %% [markdown]
# Fill blank cells with NA's

# %%
fall18.replace(r'', np.NaN, inplace=True)
fall18.head()
# Out:
#   Fraternity Dec 9 Dec 2 Nov 30 Oct 18
# 0    Chi Phi    20     4     21     12
# 1   Sigma Pi   NaN     5     16     11
# 2        SAE   NaN   NaN    NaN      6
# 3       Elmo   NaN   NaN    NaN    NaN
# 4  Delta Sig   NaN   NaN    2.5    NaN

# %% [markdown]
# Tidy the dataframe by melting the week columns into a better format

# %%
fall18 = pd.melt(fall18, id_vars=['Fraternity'], value_vars=fall18.columns[1:])
fall18.columns=['Fraternity', 'Week', 'Bags']
fall18.head()
# Out:
#   Fraternity   Week Bags
# 0    Chi Phi  Dec 9   20
# 1   Sigma Pi  Dec 9  NaN
# 2        SAE  Dec 9  NaN
# 3       Elmo  Dec 9  NaN
# 4  Delta Sig  Dec 9  NaN

# %% [markdown]
# Convert "Week" column into standard date-time string, and convert to date-time type

# %%
fall18['Week'] = fall18['Week'].apply(lambda x: x + ' 18')
fall18['Week']= pd.to_datetime(fall18['Week'].astype(str), format='%b %d %y')
fall18.head()
# Out:
#   Fraternity       Week Bags
# 0    Chi Phi 2018-12-09   20
# 1   Sigma Pi 2018-12-09  NaN
# 2        SAE 2018-12-09  NaN
# 3       Elmo 2018-12-09  NaN
# 4  Delta Sig 2018-12-09  NaN

# %% [markdown]
# Fill NaN with 0's and convert "Bags" column to float type.

# %%
fall18.fillna(0, inplace=True)
fall18['Bags'] = pd.to_numeric(fall18['Bags'])
fall18.head()
# Out:
#   Fraternity       Week  Bags
# 0    Chi Phi 2018-12-09  20.0
# 1   Sigma Pi 2018-12-09   0.0
# 2        SAE 2018-12-09   0.0
# 3       Elmo 2018-12-09   0.0
# 4  Delta Sig 2018-12-09   0.0

# %% [markdown]
# Add "Fall 2018" label. Enjoy clean and tidy data!

# %%
fall18['Semester'] = 'Fall 2018'
fall18.head()
# Out:
#   Fraternity       Week  Bags   Semester
# 0    Chi Phi 2018-12-09  20.0  Fall 2018
# 1   Sigma Pi 2018-12-09   0.0  Fall 2018
# 2        SAE 2018-12-09   0.0  Fall 2018
# 3       Elmo 2018-12-09   0.0  Fall 2018
# 4  Delta Sig 2018-12-09   0.0  Fall 2018

# %% [markdown]
# # Spring 2018 Data Cleaning

# %% [markdown]
# Open and save the "Copy of Spring 2018 Pickup Schedule" Google Sheets document, specifically the "Data-Analysis" sheet

# %%
#Opening the worksheet by using Worksheet ID
spring18_spreadsheet_key = '1QMK71zz__7E9JucmevrADed7H7etXxCP9X9c9lnSNI4'
spring18_workbook = gc.open_by_key(spring18_spreadsheet_key)

#Selecting which sheet to pulling the data
spring18_sheet = spring18_workbook.worksheet('Data-Analysis')

#Pulling the data and transform it to the data frame
spring18_values = spring18_sheet.get_all_values()
spring18 = pd.DataFrame(spring18_values[1:], columns = spring18_values[0])

# %% [markdown]
# Open the dataframe

# %%
spring18.head()
# Out:
#        Sunday, Feb 4 Sunday, Feb 11       Sunday, Feb 18     Sunday, Feb 25  \
# 0  Chi Psi: 6.5 bags                   Pi Kapp: 5.5 bags   Theta Chi: 1 bag
# 1                                      Chi Phi: 1.5 bags  Alpha Sig: 2 bags
# 2                                    Alpha Sig: 5.5 bags
# 3
# 4
#
#   Sunday, Mar 4 Sunday, Mar 11   Sunday, Mar 18       Sunday, Mar 25  \
# 0                                  ATO: 16 bags      Chi Phi: 4 bags
# 1                                   KA: 24 bags          TKE: 5 bags
# 2                               Chi Phi: 7 bags        ATO: 4.5 bags
# 3                               Phi Psi: 4 bags  Alpha sig: 3.5 bags
# 4                                    SAE: 1 bag   Sigma pi: 2.5 bags
#
#       Sunday, Apr 1        Sunday, Apr 8   Sunday, Apr 15
# 0  Theta Chi: 1 bag  Alpha Sig: 6.5 bags  Sigma Pi: 1 bag
# 1                          TKE: 0.5 bags   Pi Kapp: 1 bag
# 2                             ATO: 1 bag      KA: 19 bags
# 3                      Pi Kapp: 2.5 bags      SAE: 5 bags
# 4

# %% [markdown]
# Fill blank cells with NA's

# %%
spring18.replace(r'', np.NaN, inplace=True)
spring18.head()
# Out:
#        Sunday, Feb 4  Sunday, Feb 11       Sunday, Feb 18     Sunday, Feb 25  \
# 0  Chi Psi: 6.5 bags             NaN    Pi Kapp: 5.5 bags   Theta Chi: 1 bag
# 1                NaN             NaN    Chi Phi: 1.5 bags  Alpha Sig: 2 bags
# 2                NaN             NaN  Alpha Sig: 5.5 bags                NaN
# 3                NaN             NaN                  NaN                NaN
# 4                NaN             NaN                  NaN                NaN
#
#    Sunday, Mar 4  Sunday, Mar 11   Sunday, Mar 18       Sunday, Mar 25  \
# 0            NaN             NaN     ATO: 16 bags      Chi Phi: 4 bags
# 1            NaN             NaN      KA: 24 bags          TKE: 5 bags
# 2            NaN             NaN  Chi Phi: 7 bags        ATO: 4.5 bags
# 3            NaN             NaN  Phi Psi: 4 bags  Alpha sig: 3.5 bags
# 4            NaN             NaN       SAE: 1 bag   Sigma pi: 2.5 bags
#
#       Sunday, Apr 1        Sunday, Apr 8   Sunday, Apr 15
# 0  Theta Chi: 1 bag  Alpha Sig: 6.5 bags  Sigma Pi: 1 bag
# 1               NaN        TKE: 0.5 bags   Pi Kapp: 1 bag
# 2               NaN           ATO: 1 bag      KA: 19 bags
# 3               NaN    Pi Kapp: 2.5 bags      SAE: 5 bags
# 4               NaN                  NaN              NaN

# %% [markdown]
# Transpose the dataframe (inverse rows and columns)

# %%
spring18 = spring18.transpose()
spring18.head()
# Out:
#                                 0                  1                    2  \
# Sunday, Feb 4   Chi Psi: 6.5 bags                NaN                  NaN
# Sunday, Feb 11                NaN                NaN                  NaN
# Sunday, Feb 18  Pi Kapp: 5.5 bags  Chi Phi: 1.5 bags  Alpha Sig: 5.5 bags
# Sunday, Feb 25   Theta Chi: 1 bag  Alpha Sig: 2 bags                  NaN
# Sunday, Mar 4                 NaN                NaN                  NaN
#
#                   3    4    5
# Sunday, Feb 4   NaN  NaN  NaN
# Sunday, Feb 11  NaN  NaN  NaN
# Sunday, Feb 18  NaN  NaN  NaN
# Sunday, Feb 25  NaN  NaN  NaN
# Sunday, Mar 4   NaN  NaN  NaN

# %% [markdown]
# Make the index it's own column, labeled "Week"

# %%
spring18['Week'] = spring18.index
spring18.head()
# Out:
#                                 0                  1                    2  \
# Sunday, Feb 4   Chi Psi: 6.5 bags                NaN                  NaN
# Sunday, Feb 11                NaN                NaN                  NaN
# Sunday, Feb 18  Pi Kapp: 5.5 bags  Chi Phi: 1.5 bags  Alpha Sig: 5.5 bags
# Sunday, Feb 25   Theta Chi: 1 bag  Alpha Sig: 2 bags                  NaN
# Sunday, Mar 4                 NaN                NaN                  NaN
#
#                   3    4    5            Week
# Sunday, Feb 4   NaN  NaN  NaN   Sunday, Feb 4
# Sunday, Feb 11  NaN  NaN  NaN  Sunday, Feb 11
# Sunday, Feb 18  NaN  NaN  NaN  Sunday, Feb 18
# Sunday, Feb 25  NaN  NaN  NaN  Sunday, Feb 25
# Sunday, Mar 4   NaN  NaN  NaN   Sunday, Mar 4

# %% [markdown]
# Tidy the dataframe by melting the columns into a better format

# %%
spring18 = pd.melt(spring18, id_vars=['Week'], value_vars=spring18.columns[:-1])
spring18.drop(columns=['variable'], inplace=True) # drop irrelevant column
spring18.columns=['Week', 'Fraternity']
spring18.head()
# Out:
#              Week         Fraternity
# 0   Sunday, Feb 4  Chi Psi: 6.5 bags
# 1  Sunday, Feb 11                NaN
# 2  Sunday, Feb 18  Pi Kapp: 5.5 bags
# 3  Sunday, Feb 25   Theta Chi: 1 bag
# 4   Sunday, Mar 4                NaN

# %% [markdown]
# Extract number of bags and fraternity label into own columns, convert bags to numeric type

# %%
spring18['Bags'] = spring18['Fraternity'].str.split(': ', expand=True)[1].str.split(' bag', expand=True)[0]
spring18['Fraternity'] = spring18['Fraternity'].str.split(': ', expand=True)[0]
spring18.head()
# Out:
#              Week Fraternity  Bags
# 0   Sunday, Feb 4    Chi Psi   6.5
# 1  Sunday, Feb 11        NaN  None
# 2  Sunday, Feb 18    Pi Kapp   5.5
# 3  Sunday, Feb 25  Theta Chi     1
# 4   Sunday, Mar 4        NaN  None

# %% [markdown]
# Fill NAN in "Bags" column with 0's and convert column to float type

# %%
spring18['Bags'].fillna(0, inplace=True)
spring18['Bags'] = pd.to_numeric(spring18['Bags'])
spring18.head()
# Out:
#              Week Fraternity  Bags
# 0   Sunday, Feb 4    Chi Psi   6.5
# 1  Sunday, Feb 11        NaN   0.0
# 2  Sunday, Feb 18    Pi Kapp   5.5
# 3  Sunday, Feb 25  Theta Chi   1.0
# 4   Sunday, Mar 4        NaN   0.0

# %% [markdown]
# Replace inconsistent fraternity labels with standard label

# %%
spring18['Fraternity'].replace('Pi Kapp', 'Pi Kappa Phi', inplace=True)
spring18['Fraternity'].replace('Alpha sig', 'Alpha Sig', inplace=True)
spring18['Fraternity'].replace('Sigma pi', 'Sigma Pi', inplace=True)
spring18.head()
# Out:
#              Week    Fraternity  Bags
# 0   Sunday, Feb 4       Chi Psi   6.5
# 1  Sunday, Feb 11           NaN   0.0
# 2  Sunday, Feb 18  Pi Kappa Phi   5.5
# 3  Sunday, Feb 25     Theta Chi   1.0
# 4   Sunday, Mar 4           NaN   0.0

# %% [markdown]
# Remove rows with NAN values in the "Fraternity" column

# %%
spring18 = spring18[spring18['Fraternity'].notnull()]
spring18.head()
# Out:
#              Week    Fraternity  Bags
# 0   Sunday, Feb 4       Chi Psi   6.5
# 2  Sunday, Feb 18  Pi Kappa Phi   5.5
# 3  Sunday, Feb 25     Theta Chi   1.0
# 6  Sunday, Mar 18           ATO  16.0
# 7  Sunday, Mar 25       Chi Phi   4.0

# %% [markdown]
# Convert "Week" column into standard date-time string, and convert to date-time type

# %%
spring18['Week'] = spring18['Week'].str.split(" ", 1, expand=True)[1] + ' 18'
spring18['Week']= pd.to_datetime(spring18['Week'].astype(str), format='%b %d %y')
spring18.head()
# Out:
#         Week    Fraternity  Bags
# 0 2018-02-04       Chi Psi   6.5
# 2 2018-02-18  Pi Kappa Phi   5.5
# 3 2018-02-25     Theta Chi   1.0
# 6 2018-03-18           ATO  16.0
# 7 2018-03-25       Chi Phi   4.0

# %% [markdown]
# Add "Spring 2018" label. Enjoy clean and tidy data!

# %%
spring18['Semester'] = 'Spring 2018'
spring18.head()
# Out:
#         Week    Fraternity  Bags     Semester
# 0 2018-02-04       Chi Psi   6.5  Spring 2018
# 2 2018-02-18  Pi Kappa Phi   5.5  Spring 2018
# 3 2018-02-25     Theta Chi   1.0  Spring 2018
# 6 2018-03-18           ATO  16.0  Spring 2018
# 7 2018-03-25       Chi Phi   4.0  Spring 2018

# %% [markdown]
# # Fall 2017 Data Cleaning

# %% [markdown]
# Open and save the "Copy of  Pickup Schedule" Google Sheets document, specifically the "Data-Analysis" sheet

# %%
#Opening the worksheet by using Worksheet ID
fall17_spreadsheet_key = '1Ew11cMZ7e1VhT0hYVpTf41dthT6JZzET-a2bD3yUiq4'
fall17_workbook = gc.open_by_key(fall17_spreadsheet_key)

#Selecting which sheet to pulling the data
fall17_sheet = fall17_workbook.worksheet('Data-Analysis')

#Pulling the data and transform it to the data frame
fall17_values = fall17_sheet.get_all_values()
fall17 = pd.DataFrame(fall17_values[1:], columns = fall17_values[0])

# %% [markdown]
# Open the dataframe

# %%
fall17.head()
# Out:
#          Sunday, Sep 3         Sunday, Sep 10              Sunday, Sep 17  \
# 0    Pi Kapp: 3 sorted  Delta Sig: 1 unsorted                Phi Delt: 0
# 1       DU: 4.5 sorted                         Delta Sig: 0.5 bags sorted
# 2  Phi Psi: 1.5 sorted                                Phi Psi: 1.5 sorted
# 3
# 4
#
#         Sunday, Sep 24        Sunday, Oct 8     Sunday, Oct 15  \
# 0        ATO: 3 sorted        ATO: 1 sorted
# 1  Pi Kapp: 3.5 sorted           Chi Phi: 0  Alpha Sig: 2 bags
# 2                        Phi Delt: 1 sorted
# 3                       Pi Kapp: 2.5 sorted
# 4
#
#      Tuesday, Oct 24       Sunday, Oct 29        Sunday, Nov 5  \
# 0        ATO: 5 bags  Alpha Sig: 3.5 bags  Alpha Sig: 1.5 bags
# 1  Alpha Sig: 6 bags      Pi Kapp: 2 bags
# 2   Phi Delt: 3 bags      Phi Psi: 4 bags
# 3    Pi Kapp: 3 bags
# 4  Phi Psi: 1.5 bags
#
#        Sunday, Nov 12         Sunday, Nov 19   Thursday, Nov 26
# 0     Chi Psi: 5 bags        Chi Phi: 7 bags
# 1  The Hall: 1.5 bags  Phi Society: 0.5 bags       ATO: 10 bags
# 2   Alpha Sig: 4 bags    Alpha Sig: 2.5 bags  Chi Phi: 1.5 bags
# 3   Phi Psi: 1.5 bags        Phi Psi: 5 bags
# 4

# %% [markdown]
# Fill blank cells with NA's

# %%
fall17.replace(r'', np.NaN, inplace=True)
fall17.head()
# Out:
#          Sunday, Sep 3         Sunday, Sep 10              Sunday, Sep 17  \
# 0    Pi Kapp: 3 sorted  Delta Sig: 1 unsorted                Phi Delt: 0
# 1       DU: 4.5 sorted                    NaN  Delta Sig: 0.5 bags sorted
# 2  Phi Psi: 1.5 sorted                    NaN         Phi Psi: 1.5 sorted
# 3                  NaN                    NaN                         NaN
# 4                  NaN                    NaN                         NaN
#
#         Sunday, Sep 24        Sunday, Oct 8     Sunday, Oct 15  \
# 0        ATO: 3 sorted        ATO: 1 sorted                NaN
# 1  Pi Kapp: 3.5 sorted           Chi Phi: 0  Alpha Sig: 2 bags
# 2                  NaN   Phi Delt: 1 sorted                NaN
# 3                  NaN  Pi Kapp: 2.5 sorted                NaN
# 4                  NaN                  NaN                NaN
#
#      Tuesday, Oct 24       Sunday, Oct 29        Sunday, Nov 5  \
# 0        ATO: 5 bags  Alpha Sig: 3.5 bags  Alpha Sig: 1.5 bags
# 1  Alpha Sig: 6 bags      Pi Kapp: 2 bags                  NaN
# 2   Phi Delt: 3 bags      Phi Psi: 4 bags                  NaN
# 3    Pi Kapp: 3 bags                  NaN                  NaN
# 4  Phi Psi: 1.5 bags                  NaN                  NaN
#
#        Sunday, Nov 12         Sunday, Nov 19   Thursday, Nov 26
# 0     Chi Psi: 5 bags        Chi Phi: 7 bags                NaN
# 1  The Hall: 1.5 bags  Phi Society: 0.5 bags       ATO: 10 bags
# 2   Alpha Sig: 4 bags    Alpha Sig: 2.5 bags  Chi Phi: 1.5 bags
# 3   Phi Psi: 1.5 bags        Phi Psi: 5 bags                NaN
# 4                 NaN                    NaN                NaN

# %% [markdown]
# Transpose the dataframe (inverse rows and columns)

# %%
fall17 = fall17.transpose()
fall17.head()
# Out:
#                                     0                           1  \
# Sunday, Sep 3       Pi Kapp: 3 sorted              DU: 4.5 sorted
# Sunday, Sep 10  Delta Sig: 1 unsorted                         NaN
# Sunday, Sep 17           Phi Delt: 0   Delta Sig: 0.5 bags sorted
# Sunday, Sep 24          ATO: 3 sorted         Pi Kapp: 3.5 sorted
# Sunday, Oct 8           ATO: 1 sorted                  Chi Phi: 0
#
#                                   2                    3    4
# Sunday, Sep 3   Phi Psi: 1.5 sorted                  NaN  NaN
# Sunday, Sep 10                  NaN                  NaN  NaN
# Sunday, Sep 17  Phi Psi: 1.5 sorted                  NaN  NaN
# Sunday, Sep 24                  NaN                  NaN  NaN
# Sunday, Oct 8    Phi Delt: 1 sorted  Pi Kapp: 2.5 sorted  NaN

# %% [markdown]
# Make the index it's own column, labeled "Week"

# %%
fall17['Week'] = fall17.index
fall17.head()
# Out:
#                                     0                           1  \
# Sunday, Sep 3       Pi Kapp: 3 sorted              DU: 4.5 sorted
# Sunday, Sep 10  Delta Sig: 1 unsorted                         NaN
# Sunday, Sep 17           Phi Delt: 0   Delta Sig: 0.5 bags sorted
# Sunday, Sep 24          ATO: 3 sorted         Pi Kapp: 3.5 sorted
# Sunday, Oct 8           ATO: 1 sorted                  Chi Phi: 0
#
#                                   2                    3    4            Week
# Sunday, Sep 3   Phi Psi: 1.5 sorted                  NaN  NaN   Sunday, Sep 3
# Sunday, Sep 10                  NaN                  NaN  NaN  Sunday, Sep 10
# Sunday, Sep 17  Phi Psi: 1.5 sorted                  NaN  NaN  Sunday, Sep 17
# Sunday, Sep 24                  NaN                  NaN  NaN  Sunday, Sep 24
# Sunday, Oct 8    Phi Delt: 1 sorted  Pi Kapp: 2.5 sorted  NaN   Sunday, Oct 8

# %% [markdown]
# Tidy the dataframe by melting the columns into a better format

# %%
fall17 = pd.melt(fall17, id_vars=['Week'], value_vars=fall17.columns[:-1])
fall17.drop(columns=['variable'], inplace=True) # drop irrelevant column
fall17.columns=['Week', 'Fraternity']
fall17.head()
# Out:
#              Week             Fraternity
# 0   Sunday, Sep 3      Pi Kapp: 3 sorted
# 1  Sunday, Sep 10  Delta Sig: 1 unsorted
# 2  Sunday, Sep 17           Phi Delt: 0
# 3  Sunday, Sep 24          ATO: 3 sorted
# 4   Sunday, Oct 8          ATO: 1 sorted

# %% [markdown]
# Extract number of bags and fraternity label into own columns, convert bags to numeric type

# %%
fall17['Bags'] = fall17['Fraternity'].str.split(': ', expand=True)[1].str.split(' ', expand=True)[0]
fall17['Fraternity'] = fall17['Fraternity'].str.split(': ', expand=True)[0]
fall17.head()
# Out:
#              Week Fraternity Bags
# 0   Sunday, Sep 3    Pi Kapp    3
# 1  Sunday, Sep 10  Delta Sig    1
# 2  Sunday, Sep 17   Phi Delt    0
# 3  Sunday, Sep 24        ATO    3
# 4   Sunday, Oct 8        ATO    1

# %% [markdown]
# Fill NAN in "Bags" column with 0's and convert column to float type

# %%
fall17['Bags'].fillna(0, inplace=True)
fall17['Bags'] = pd.to_numeric(fall17['Bags'])
fall17.head()
# Out:
#              Week Fraternity  Bags
# 0   Sunday, Sep 3    Pi Kapp   3.0
# 1  Sunday, Sep 10  Delta Sig   1.0
# 2  Sunday, Sep 17   Phi Delt   0.0
# 3  Sunday, Sep 24        ATO   3.0
# 4   Sunday, Oct 8        ATO   1.0

# %% [markdown]
# Replace inconsistent fraternity labels with standard label

# %%
fall17['Fraternity'].replace('Pi Kapp', 'Pi Kappa Phi', inplace=True)
fall17.head()
# Out:
#              Week    Fraternity  Bags
# 0   Sunday, Sep 3  Pi Kappa Phi   3.0
# 1  Sunday, Sep 10     Delta Sig   1.0
# 2  Sunday, Sep 17      Phi Delt   0.0
# 3  Sunday, Sep 24           ATO   3.0
# 4   Sunday, Oct 8           ATO   1.0

# %% [markdown]
# Remove rows with NAN values in the "Fraternity" column

# %%
fall17 = fall17[fall17['Fraternity'].notnull()]
fall17.head()
# Out:
#              Week    Fraternity  Bags
# 0   Sunday, Sep 3  Pi Kappa Phi   3.0
# 1  Sunday, Sep 10     Delta Sig   1.0
# 2  Sunday, Sep 17      Phi Delt   0.0
# 3  Sunday, Sep 24           ATO   3.0
# 4   Sunday, Oct 8           ATO   1.0

# %% [markdown]
# Convert "Week" column into standard date-time string, and convert to date-time type

# %%
fall17['Week'] = fall17['Week'].str.split(", ", 1, expand=True)[1] + ' 17'
fall17['Week']= pd.to_datetime(fall17['Week'].astype(str), format='%b %d %y')
fall17.head()
# Out:
#         Week    Fraternity  Bags
# 0 2017-09-03  Pi Kappa Phi   3.0
# 1 2017-09-10     Delta Sig   1.0
# 2 2017-09-17      Phi Delt   0.0
# 3 2017-09-24           ATO   3.0
# 4 2017-10-08           ATO   1.0

# %% [markdown]
# Add "Fall 2017" label. Enjoy clean and tidy data!

# %%
fall17['Semester'] = 'Fall 2017'
fall17.head()
# Out:
#         Week    Fraternity  Bags   Semester
# 0 2017-09-03  Pi Kappa Phi   3.0  Fall 2017
# 1 2017-09-10     Delta Sig   1.0  Fall 2017
# 2 2017-09-17      Phi Delt   0.0  Fall 2017
# 3 2017-09-24           ATO   3.0  Fall 2017
# 4 2017-10-08           ATO   1.0  Fall 2017

# %% [markdown]
# ### Quick Graphs for total bags across all houses

# %%
totals = pd.concat([spring20, fall19, spring19, fall18, spring18, fall17], axis=0, sort=False)

# %%
totals['Bags'].sum()
# Out:
# 1715.5

# %%
weekly = totals.groupby(['Week']).sum()

# %%
weekly.reset_index(level=0, inplace=True)

# %%
weekly['Cumulative Bags'] = weekly['Bags'].cumsum()

# %%
sns.lineplot(weekly['Week'], weekly['Bags'], linewidth=2.0)

# %%
sns.lineplot(weekly['Week'], weekly['Cumulative Bags'], linewidth=2.0)
